# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# input
csv_dir = "/content/drive/MyDrive/Colab Notebooks/Drain_result/"
dataset_prefix = "thunderbird_10M."
csv_structured = csv_dir + dataset_prefix + "log_ident_structured.csv"
csv_template = csv_dir + dataset_prefix + "log_ident_templates.csv"

test_portion = 0.6

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import RegexpTokenizer

import os
from tqdm.auto import tqdm
tqdm.pandas()

import re
from sklearn.model_selection import train_test_split

seed = 42
np.random.seed(seed)

# %%
def define_dtype(df, dtype_map, copy=False):
  if copy: df = df.copy()
  
  for col, dtype in dtype_map.items():
    if col not in df.columns: continue
    if dtype.startswith("datetime_format_"):
      dtype, format = dtype.split("_format_")
      df[col] = pd.to_datetime(df[col], format=format)
    elif dtype == "_drop_": df = df.drop(columns=[col])
    else: df[col] = df[col].astype(dtype)
  
  return df

# %%
struct_log = pd.read_csv(csv_structured)
template_log = pd.read_csv(csv_template)

# %%
struct_log["Content"].sample(10)
# Out:
# 5135240    jAIFpXvU024714: from=root, size=1541310, class...
# 1125753                         file-max limit 65536 reached
# 2034180    Instrumentation Service EventID: 1052 Temperat...
# 2720846          [ib_sm_sweep.c:1264]: Rediscover the subnet
# 9372604                          Got trap from peer on fd 13
# 8702341    Instrumentation Service EventID: 1052 Temperat...
# 4288613    unable to qualify my own domain name (aadmin1)...
# 6232578    [KERNEL_IB][tsIbTavorMadProcess][/mnt_projects...
# 4473673    Instrumentation Service EventID: 1053 Temperat...
# 6861009    Cannot open file /var/log/syslog-ng/an21/2005....
# Name: Content, dtype: object

# %%
struct_log[["Label", "Timestamp", "Date", "User", "Month", "Day", "Time", "Location", "Component", "PID", "Content"]]
# Out:
#         Label   Timestamp        Date          User Month  Day      Time  \
# 0           -  1131523501  2005.11.09       aadmin1   Nov   10  00:05:01
# 1           -  1131524071  2005.11.09  tbird-admin1   Nov   10  00:14:31
# 2           -  1131524073  2005.11.09  tbird-admin1   Nov   10  00:14:33
# 3           -  1131524106  2005.11.09  tbird-admin1   Nov   10  00:15:06
# 4           -  1131524107  2005.11.09  tbird-admin1   Nov   10  00:15:07
# ...       ...         ...         ...           ...   ...  ...       ...
# 9975127     -  1133756956  2005.12.04         bn171   Dec    4  20:29:16
# 9975128     -  1133756956  2005.12.04         bn190   Dec    4  20:29:16
# 9975129     -  1133756956  2005.12.04         bn190   Dec    4  20:29:16
# 9975130     -  1133756956  2005.12.04         dn536   Dec    4  20:29:16
# 9975131     -  1133756957  2005.12.04     tbird-sm1   Dec    4  20:29:17
#
#                    Location             Component      PID  \
# 0               src@aadmin1              in.tftpd  14620.0
# 1        local@tbird-admin1      postfix/postdrop  10896.0
# 2        local@tbird-admin1      postfix/postdrop  10900.0
# 3        local@tbird-admin1      postfix/postdrop  10910.0
# 4        local@tbird-admin1      postfix/postdrop  10913.0
# ...                     ...                   ...      ...
# 9975127         bn171/bn171                 snmpd   7944.0
# 9975128         bn190/bn190  Server Administrator      NaN
# 9975129         bn190/bn190                 snmpd   7941.0
# 9975130         dn536/dn536                  ntpd   2283.0
# 9975131       src@tbird-sm1               ib_sm.x  24904.0
#
#                                                    Content
# 0                     tftp: client does not accept options
# 1        warning: unable to look up public/pickup: No s...
# 2        warning: unable to look up public/pickup: No s...
# 3        warning: unable to look up public/pickup: No s...
# 4        warning: unable to look up public/pickup: No s...
# ...                                                    ...
# 9975127                        Got trap from peer on fd 13
# 9975128  Instrumentation Service EventID: 1052 Temperat...
# 9975129                        Got trap from peer on fd 13
# 9975130           synchronized to 10.100.30.250, stratum 3
# 9975131  [ib_sm_sweep.c:1831]: ********************** N...
#
# [9975132 rows x 11 columns]

# %%
struct_dtype = {
    "LineId": "int64",
    "Label": "category",
    "Timestamp": "int64",
    "Date": "datetime64",
    "User": "string",
    "Month": "category",
    "Day": "int8",
    "Time": "datetime_format_%H:%M:%S",
    "Location": "string",
    "PID": "string",
    "Content": "string",
    "EventId": "string",
    "EventTemplate": "string",
    "EventTemplateIdent": "string",
    "ParameterList": "object",
}

template_dtype = {
    "EventId": "string",
    "EventTemplateIdent": "string",
    "Occurrences": "int64"
}

# %%
struct_log = define_dtype(struct_log, struct_dtype)
template_log = define_dtype(template_log, template_dtype)

# %%
trainset, testset = train_test_split(struct_log, test_size=test_portion, random_state=seed, shuffle=False)

# %%
train_eventId = trainset["EventId"]
test_eventId = testset["EventId"]

train_template = template_log.query("EventId in @train_eventId")
test_template = template_log.query("EventId in @test_eventId")

# %%
unique_trainset = pd.DataFrame(
    trainset["Content"].unique(),
    columns=["Content"]
    )

# %%
tokenizer = RegexpTokenizer(r'[^\s[\](),=<>{}+*]+')
unique_trainset["Tokens"] = unique_trainset["Content"].progress_apply(tokenizer.tokenize)
# Out:
#   0%|          | 0/372757 [00:00<?, ?it/s]

# %%
import tensorflow as tf
from zlib import crc32

class DenoiseAutoEncoder(tf.keras.Model):

  def __init__(self, regex_features, kernel_size, batch_size, padding_token="<PAD>", **kwargs):
    super(DenoiseAutoEncoder, self).__init__(**kwargs)
    self.batch_size = batch_size
    self.regex_features = regex_features
    self.n_features = len(self.regex_features) + 2
    self.features = None
    self.kernel_size = (kernel_size, )
    self.min_length = kernel_size
    self.pad_token = self.string_to_float_crc32(padding_token)

    self.encoder = tf.keras.Sequential([
        tf.keras.layers.Input(
            shape=(None, self.n_features),
            name="input_layer",
            dtype="float64",
        ),
        tf.keras.layers.Conv1D(
            filters=8,
            kernel_size=self.kernel_size,
            strides=1,
            padding="same",
            activation="relu",
            dtype="float64",
        ),
        tf.keras.layers.Conv1D(
            filters=4,
            kernel_size=self.kernel_size,
            strides=1,
            padding="same",
            activation="relu",
            dtype="float64",
        )
    ])

    self.decoder = tf.keras.Sequential([
        tf.keras.layers.Conv1DTranspose(
            filters=4,
            kernel_size=self.kernel_size,
            strides=1,
            padding='same',
            activation="relu",
            dtype="float64",
        ),
        tf.keras.layers.Conv1DTranspose(
            filters=8,
            kernel_size=self.kernel_size,
            strides=1,
            padding='same',
            activation="relu",
            dtype="float64",
        ),
        tf.keras.layers.Conv1D(
            filters=1,
            kernel_size=self.kernel_size,
            strides=1,
            activation="sigmoid",
            padding='same',
            dtype="float64",
        ),
        tf.keras.layers.Reshape((-1,), dtype="float64",)
    ])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

  def fit_vocab(self, X):
    vocab = [ token for row in X for token in row ]
    vocab.append(self.pad_token)
    self.vocab = np.unique(vocab)

    regex_features = np.ones(
        shape=(len(self.vocab), len(self.regex_features)), 
        dtype="float64"
        )
    hash_features = np.ones(shape=(len(self.vocab),), dtype="float64")
    len_features = np.ones(shape=(len(self.vocab),), dtype="uint8")
    for i, token in tqdm(
        enumerate(self.vocab), 
        desc="extract features",
        total=len(self.vocab)
        ):
      for j, regex in enumerate(self.regex_features):
        regex_features[i][j] = self.extract_regex_percentage(token, regex)
      
      hash_features[i] = self.string_to_float_crc32(token)
      len_features[i] = len(token)

    self.mean_len_token = len_features.mean()
    self.std_len_token = len_features.std()
    norm_len_features = (
        ( len_features - self.mean_len_token ) / ( self.std_len_token )
        ).astype("float64")

    self.features = pd.DataFrame(
        regex_features, 
        index=self.vocab, 
        columns=self.regex_features
    )
    self.features["crc32"] = hash_features
    self.features["norm_len"] =  norm_len_features

  def pad(self, X):
    return [ 
        ( seq if len(seq) >= self.min_length \
          else seq.extend([self.pad_token for _ in range(self.min_length - len(seq))]) )\
        for seq in tqdm(X, desc="padding sequence") ]

  def asstr(self, X):
    return [ str(x) for x in X]

  def transform_features(self, X):
    assert not self.features is None, \
      "require to call fit_vocab() before extract_features"

    Y = [ self.extract_features(seq) \
            for seq in tqdm(X, desc="extract feature") ]
    return Y

  def extract_label(self, X):
    Y = [ [ self.string_to_float_crc32(token) for token in seq ] \
              for seq in tqdm(X, desc="extract feature") ]
    return Y

  def extract_features(self, x):
    assert not self.features is None, \
      "require to call fit_vocab() before extract_features"

    _features = np.zeros(shape=(len(x), self.n_features), dtype="float64")
    for i, token in enumerate(x):
      for j, regex in enumerate(self.regex_features):
        _features[i][j] = self.extract_regex_percentage(token, regex)
      
      _features[i][-2] = self.string_to_float_crc32(token)
      _features[i][-1] = (
          (len(token) - self.mean_len_token) / ( self.std_len_token )
          ).astype("float64")
    
    return _features

  @staticmethod
  def extract_regex_percentage(token, regex):
    found = re.findall(regex, token)
    count = sum([ len(m) for m in found ])
    return count / len(token)

  @staticmethod
  def string_to_float_crc32(text, encoding="utf-8"):
    return float(crc32(text.encode(encoding=encoding))) / 2**32

# %%
denoiser = DenoiseAutoEncoder(
    regex_features={
        "[0-9]+",
        "[a-fA-F0-9]+",
        "[A-F]+",
        "[a-f]+",
        # "[\\/]+",
        # "[:]+",
        # "[.]+",
        # "[^A-Za-z0-9]+",
    },
    kernel_size = 3,
    batch_size = 1
)

# %%
denoiser.compile(
    optimizer='adam', 
    loss=tf.losses.MeanAbsoluteError()
    )

# %%
denoiser.fit_vocab(unique_trainset["Tokens"])
# Out:
# extract features:   0%|          | 0/120638 [00:00<?, ?it/s]

# %%
unique_trainset["Tokens_pad"] = pd.Series(denoiser.pad(unique_trainset["Tokens"]))
unique_trainset["Tokens_pad"] = unique_trainset["Tokens_pad"].map(denoiser.asstr)
# Out:
# padding sequence:   0%|          | 0/372757 [00:00<?, ?it/s]

# %%
train_X = denoiser.transform_features(unique_trainset["Tokens_pad"])
train_Y = denoiser.extract_label(unique_trainset["Tokens_pad"])
# Out:
# extract feature:   0%|          | 0/372757 [00:00<?, ?it/s]
# extract feature:   0%|          | 0/372757 [00:00<?, ?it/s]

# %%
def gen_series(X, y):
  assert len(X) == len(y), "length of X and y must equal."
  for i in range(len(X)):
    yield X[i], y[i]

# %%
train_set = tf.data.Dataset.from_generator(
    lambda: gen_series(train_X, train_Y),
    output_signature=(
        tf.TensorSpec(
            shape=(None, denoiser.n_features), 
            dtype="float64",
            name="features"
            ),
        tf.TensorSpec(
            shape=(None,), 
            dtype="float64",
            name="labels"
            )
        )
)
train_set = train_set.apply( tf.data.experimental.assert_cardinality(len(train_X)) )

# %%
train_batch = train_set.padded_batch(denoiser.batch_size)

# %%
denoiser.build(input_shape=(denoiser.batch_size, None, denoiser.n_features))

# %%
denoiser.summary()
# Out:
# Model: "denoise_auto_encoder_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, None, 4)           252
#
#  sequential_3 (Sequential)   (1, None)                 181
#
# =================================================================
# Total params: 433
# Trainable params: 433
# Non-trainable params: 0
# _________________________________________________________________

# %%
for x, y in train_batch:
  print(x.shape, y.shape)
  y_hat = denoiser(x)
  print(y_hat.shape)
  break
# Out:
# (1, 6, 6) (1, 6)
# (1, 6)

# %%
denoiser.fit(train_batch, epochs=1)
# Out:
# 372757/372757 [==============================] - 688s 2ms/step - loss: 0.0019

# %%
pred = denoiser.predict(train_batch)
# Out:
# 372757/372757 [==============================] - 514s 1ms/step

# %%
# with np.printoptions(precision=4, suppress=True):
for i, data in enumerate(train_batch):
  text = " ".join([ f"{t}" for t in unique_trainset["Tokens"].iloc[i] ]) 
  if text.endswith("via eth1"):
    print("text:", text)
    # print(data[1])
    # print(pred[i])
    print("diff:", np.abs((data[1] - pred[i]).numpy()))
# Out:
# text: DHCPDISCOVER from 00:11:43:32:c6:8c via eth1
# diff: [[0.00051104 0.00154028 0.00421988 0.00758549 0.00019431]]
# text: DHCPOFFER on 10.100.19.66 to 00:11:43:32:c6:8c via eth1
# diff: [[0.02180106 0.01278703 0.00758098 0.00072842 0.00283269 0.00725931
#   0.00024634]]
# text: DHCPACK on 10.100.19.66 to 00:11:43:32:c6:8c via eth1
# diff: [[0.03344546 0.00138985 0.00999473 0.00029888 0.00278158 0.00726095
#   0.00024634]]
# text: DHCPREQUEST for 10.100.19.66 10.100.18.250 from 00:11:43:32:c6:8c via eth1
# diff: [[0.00503027 0.00240654 0.00938366 0.00453446 0.0038987  0.00071356
#   0.00717281 0.0001212 ]]
# text: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1
# diff: [[0.00112634 0.00305492 0.00526568 0.00885068 0.00032893]]
# text: DHCPOFFER on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# diff: [[0.02125235 0.01881509 0.00770164 0.0035928  0.00555927 0.0082173
#   0.00033217]]
# text: DHCPACK on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# diff: [[0.03438461 0.00429102 0.00443322 0.00408246 0.00556284 0.00821905
#   0.00033217]]
# text: DHCPREQUEST for 10.100.4.251 10.100.0.250 from 00:11:43:e3:ba:c3 via eth1
# diff: [[0.00409766 0.00715335 0.00104882 0.00414633 0.00569912 0.00568199
#   0.00806814 0.00040349]]
# text: DHCPDISCOVER from 00:11:43:e4:78:e8 via eth1
# diff: [[1.50314735e-04 2.24567500e-03 1.58388559e-03 8.10902242e-03
#   7.80973252e-06]]
# text: DHCPOFFER on 10.100.29.114 to 00:11:43:e4:78:e8 via eth1
# diff: [[2.20045025e-02 1.45053569e-02 6.74054714e-03 4.79292980e-04
#   6.77434837e-05 8.06990172e-03 6.96423715e-07]]
# text: DHCPACK on 10.100.29.114 to 00:11:43:e4:78:e8 via eth1
# diff: [[3.36334954e-02 3.05252969e-03 9.14977228e-03 4.61882479e-05
#   1.09931326e-04 8.07153543e-03 6.96423715e-07]]
# text: DHCPREQUEST for 10.100.29.114 10.100.28.250 from 00:11:43:e4:78:e8 via eth1
# diff: [[5.22702440e-03 3.92053819e-03 1.04468127e-02 4.58461044e-03
#   4.78154520e-03 2.33292281e-04 7.75306484e-03 5.40068851e-05]]
# text: DHCPDISCOVER from 00:11:43:e3:bd:4e via eth1
# diff: [[3.24805193e-05 2.35531627e-03 7.10042665e-04 7.45442482e-03
#   4.51561202e-05]]
# text: DHCPOFFER on 10.100.21.65 to 00:11:43:e3:bd:4e via eth1
# diff: [[2.19454317e-02 5.95533349e-03 1.00608421e-02 7.65295897e-05
#   9.22176752e-04 7.38465195e-03 3.78680263e-05]]
# text: DHCPACK on 10.100.21.65 to 00:11:43:e3:bd:4e via eth1
# diff: [[3.31292347e-02 2.35814167e-03 1.87583665e-02 4.32616807e-04
#   9.93693161e-04 7.37036248e-03 3.78680263e-05]]
# text: DHCPREQUEST for 10.100.21.65 10.100.20.250 from 00:11:43:e3:bd:4e via eth1
# diff: [[5.59506836e-03 3.77006204e-03 9.09794562e-04 1.56735060e-03
#   5.96177533e-03 8.29390871e-04 7.09320342e-03 9.66964370e-05]]
# text: DHCPDISCOVER from 00:11:43:37:f9:e8 via eth1
# diff: [[0.0003181  0.00176199 0.00545134 0.00806012 0.00027629]]
# text: DHCPOFFER on 10.100.34.7 to 00:11:43:37:f9:e8 via eth1
# diff: [[0.02079775 0.01877262 0.00053798 0.00126778 0.00341603 0.00820477
#   0.00029666]]
# text: DHCPACK on 10.100.34.7 to 00:11:43:37:f9:e8 via eth1
# diff: [[0.0340643  0.00145813 0.00541655 0.00068319 0.00331054 0.00820766
#   0.00029666]]
# text: DHCPREQUEST for 10.100.34.7 10.100.32.250 from 00:11:43:37:f9:e8 via eth1
# diff: [[0.00321374 0.00429999 0.00273083 0.00899228 0.00129201 0.00200895
#   0.00764525 0.00020202]]
# text: DHCPDISCOVER from 00:14:22:12:0a:ea via eth1
# diff: [[2.09282948e-03 1.50803907e-03 3.54952853e-02 7.43824166e-03
#   3.02953191e-05]]
# text: DHCPOFFER on 10.100.33.78 to 00:14:22:12:0a:ea via eth1
# diff: [[0.02062737 0.0198188  0.00373345 0.01062103 0.00156841 0.00186078
#   0.00053846]]
# text: DHCPACK on 10.100.33.78 to 00:14:22:12:0a:ea via eth1
# diff: [[0.0340602  0.00098138 0.0032679  0.01119724 0.00155584 0.00186393
#   0.00053846]]
# text: DHCPREQUEST for 10.100.33.78 10.100.34.250 from 00:14:22:12:0a:ea via eth1
# diff: [[0.00301012 0.00736601 0.00715488 0.00089425 0.00348417 0.00044561
#   0.00147406 0.00060072]]
# text: DHCPDISCOVER from 00:11:43:e4:86:89 via eth1
# diff: [[0.00043677 0.00171174 0.00497353 0.00827471 0.00023944]]
# text: DHCPOFFER on 10.100.18.92 to 00:11:43:e4:86:89 via eth1
# diff: [[0.02214872 0.00484817 0.0076044  0.00029547 0.0045101  0.00831536
#   0.00028273]]
# text: DHCPACK on 10.100.18.92 to 00:11:43:e4:86:89 via eth1
# diff: [[0.03282438 0.00162493 0.00850824 0.00019206 0.00447114 0.00831381
#   0.00028273]]
# text: DHCPREQUEST for 10.100.18.92 10.100.18.250 from 00:11:43:e4:86:89 via eth1
# diff: [[0.00567656 0.00145797 0.02781126 0.01001957 0.00565043 0.0010571
#   0.00786365 0.00016705]]
# text: DHCPDISCOVER from 00:11:43:e3:bf:95 via eth1
# diff: [[5.72669845e-05 3.03167539e-03 3.29693912e-03 7.16673386e-03
#   4.44612797e-04]]
# text: DHCPOFFER on 10.100.23.58 to 00:11:43:e3:bf:95 via eth1
# diff: [[0.02063195 0.01865598 0.00290417 0.00038777 0.0016559  0.00754176
#   0.00048472]]
# text: DHCPACK on 10.100.23.58 to 00:11:43:e3:bf:95 via eth1
# diff: [[0.03410466 0.00172731 0.00913631 0.00022884 0.00160009 0.0075436
#   0.00048472]]
# text: DHCPREQUEST for 10.100.23.58 10.100.22.250 from 00:11:43:e3:bf:95 via eth1
# diff: [[0.00322303 0.00886819 0.01272682 0.00345548 0.00204963 0.00161693
#   0.00677672 0.00053779]]
# text: DHCPDISCOVER from 00:11:43:e0:02:2a via eth1
# diff: [[9.16805401e-04 1.07306155e-03 7.65552187e-03 6.57909472e-03
#   2.19088703e-05]]
# text: DHCPOFFER on 10.100.80.113 to 00:11:43:e0:02:2a via eth1
# diff: [[0.0223017  0.00608709 0.01948667 0.00119296 0.00686038 0.00589234
#   0.00011566]]
# text: DHCPACK on 10.100.80.113 to 00:11:43:e0:02:2a via eth1
# diff: [[0.03304836 0.00301652 0.02309223 0.00084297 0.00677406 0.0058779
#   0.00011566]]
# text: DHCPREQUEST for 10.100.80.113 10.100.16.250 from 00:11:43:e0:02:2a via eth1
# diff: [[5.89528582e-03 3.16258551e-03 3.29427348e-02 3.04627528e-03
#   5.78372653e-03 4.43157048e-03 5.77750822e-03 2.27058031e-05]]
# text: DHCPDISCOVER from 00:11:43:e0:02:28 via eth1
# diff: [[1.20479723e-03 7.68920672e-04 8.30748739e-03 6.01455666e-03
#   8.02863924e-05]]
# text: DHCPOFFER on 10.100.16.113 to 00:11:43:e0:02:28 via eth1
# diff: [[2.14124925e-02 2.06878092e-02 6.36577432e-03 2.52871935e-03
#   6.66244699e-03 5.38543527e-03 4.04049655e-06]]
# text: DHCPACK on 10.100.16.113 to 00:11:43:e0:02:28 via eth1
# diff: [[3.45634803e-02 7.16195879e-03 3.09223963e-03 2.01649357e-03
#   6.61098557e-03 5.38717131e-03 4.04049655e-06]]
# text: DHCPREQUEST for 10.100.16.113 10.100.16.250 from 00:11:43:e0:02:28 via eth1
# diff: [[0.00362539 0.0057104  0.00262882 0.00065341 0.00112778 0.00554273
#   0.00522647 0.00012655]]
# text: DHCPDISCOVER from 00:11:43:e4:71:17 via eth1
# diff: [[0.00076102 0.00133898 0.00518086 0.00747726 0.00010164]]
# text: DHCPOFFER on 10.100.11.11 to 00:11:43:e4:71:17 via eth1
# diff: [[0.02191712 0.00972295 0.01870041 0.00068292 0.00386422 0.00694801
#   0.00017054]]
# text: DHCPACK on 10.100.11.11 to 00:11:43:e4:71:17 via eth1
# diff: [[0.03319556 0.00220479 0.02868866 0.00028243 0.00377303 0.00693368
#   0.00017054]]
# text: DHCPREQUEST for 10.100.11.11 10.100.10.250 from 00:11:43:e4:71:17 via eth1
# diff: [[5.34354448e-03 2.19422407e-03 2.03315036e-03 6.02617397e-03
#   3.79829463e-03 1.68570620e-03 7.06253535e-03 2.92314862e-05]]
# text: DHCPDISCOVER from 00:11:43:e1:7e:98 via eth1
# diff: [[8.69357772e-05 2.62870198e-03 9.80134091e-05 7.87698092e-03
#   3.60205835e-04]]
# text: DHCPOFFER on 10.100.0.53 to 00:11:43:e1:7e:98 via eth1
# diff: [[0.02179988 0.00296195 0.00248006 0.00048489 0.00148882 0.00785848
#   0.00035344]]
# text: DHCPACK on 10.100.0.53 to 00:11:43:e1:7e:98 via eth1
# diff: [[0.03284159 0.00062946 0.00823432 0.00083904 0.00155057 0.00784424
#   0.00035344]]
# text: DHCPREQUEST for 10.100.0.53 10.100.0.250 from 00:11:43:e1:7e:98 via eth1
# diff: [[0.00600313 0.00507443 0.00460252 0.00638927 0.00828705 0.00201306
#   0.00754772 0.00042951]]
# text: DHCPDISCOVER from 00:11:43:e4:b0:bc via eth1
# diff: [[0.00135796 0.00020251 0.00731957 0.00326333 0.00017129]]
# text: DHCPOFFER on 10.100.10.91 to 00:11:43:e4:b0:bc via eth1
# diff: [[0.02163131 0.01505164 0.00785334 0.00182591 0.01000138 0.00206983
#   0.00017895]]
# text: DHCPACK on 10.100.10.91 to 00:11:43:e4:b0:bc via eth1
# diff: [[0.03380738 0.00050946 0.00495724 0.0013534  0.00996311 0.00207154
#   0.00017895]]
# text: DHCPREQUEST for 10.100.10.91 10.100.10.250 from 00:11:43:e4:b0:bc via eth1
# diff: [[0.00457801 0.00302068 0.00643077 0.00189636 0.00143514 0.00477086
#   0.00233998 0.00030471]]
# text: DHCPDISCOVER from 00:11:43:e4:c5:98 via eth1
# diff: [[0.00059436 0.00144449 0.00454481 0.00738002 0.0001589 ]]
# text: DHCPOFFER on 10.100.8.91 to 00:11:43:e4:c5:98 via eth1
# diff: [[0.02105571 0.01785382 0.0059711  0.00150254 0.00289184 0.00713752
#   0.00020798]]
# text: DHCPACK on 10.100.8.91 to 00:11:43:e4:c5:98 via eth1
# diff: [[0.03418245 0.00221509 0.00267453 0.00099095 0.00283879 0.00713922
#   0.00020798]]
# text: DHCPREQUEST for 10.100.8.91 10.100.8.250 from 00:11:43:e4:c5:98 via eth1
# diff: [[3.97970407e-03 6.74714283e-03 1.30140702e-03 2.55761881e-03
#   3.53306870e-03 1.61062426e-03 6.88785875e-03 8.98523302e-05]]
# text: DHCPDISCOVER from 00:14:22:16:a3:b1 via eth1
# diff: [[0.00018368 0.00204388 0.00454462 0.00823104 0.00017772]]
# text: DHCPOFFER on 10.100.32.86 to 00:14:22:16:a3:b1 via eth1
# diff: [[0.02208001 0.00474397 0.00893941 0.00017219 0.0029765  0.00832631
#   0.0001774 ]]
# text: DHCPACK on 10.100.32.86 to 00:14:22:16:a3:b1 via eth1
# diff: [[0.0328883  0.00141387 0.02094649 0.00021781 0.00286998 0.00831211
#   0.0001774 ]]
# text: DHCPREQUEST for 10.100.32.86 10.100.32.250 from 00:14:22:16:a3:b1 via eth1
# diff: [[0.00567565 0.00169324 0.01078587 0.01062606 0.00576107 0.00300977
#   0.00791218 0.00017189]]
# text: DHCPDISCOVER from 00:11:43:de:35:80 via eth1
# diff: [[0.00098297 0.00180853 0.00698689 0.00988546 0.0008968 ]]
# text: DHCPOFFER on 10.100.67.37 to 00:11:43:de:35:80 via eth1
# diff: [[0.02156041 0.0152668  0.01144398 0.00131142 0.00623984 0.00911988
#   0.00088743]]
# text: DHCPACK on 10.100.67.37 to 00:11:43:de:35:80 via eth1
# diff: [[0.03396887 0.00084009 0.00840762 0.00177677 0.00622512 0.00912157
#   0.00088743]]
# text: DHCPREQUEST for 10.100.67.37 10.100.2.250 from 00:11:43:de:35:80 via eth1
# diff: [[0.00459698 0.00458293 0.00557509 0.00453974 0.00368366 0.00637665
#   0.00924832 0.00094992]]
# text: DHCPDISCOVER from 00:11:43:e1:7c:91 via eth1
# diff: [[0.00049094 0.00156339 0.00420607 0.00763502 0.00020285]]
# text: DHCPOFFER on 10.100.12.37 to 00:11:43:e1:7c:91 via eth1
# diff: [[0.02066135 0.0172594  0.0077574  0.00142882 0.0004631  0.007708
#   0.00022868]]
# text: DHCPDISCOVER from 00:11:43:de:35:7e via eth1
# diff: [[9.74005285e-04 8.75552049e-04 8.50743032e-03 5.64444192e-03
#   1.08240255e-05]]
# text: DHCPOFFER on 10.100.3.37 to 00:11:43:de:35:7e via eth1
# diff: [[2.14510542e-02 1.29115077e-02 7.15221040e-03 1.22197628e-03
#   7.07821140e-03 4.87844931e-03 7.62749869e-05]]
# text: DHCPACK on 10.100.12.37 to 00:11:43:e1:7c:91 via eth1
# diff: [[0.03415599 0.00533067 0.01259594 0.00079769 0.00037541 0.00770989
#   0.00022868]]
# text: DHCPREQUEST for 10.100.12.37 10.100.12.250 from 00:11:43:e1:7c:91 via eth1
# diff: [[0.00276602 0.00675018 0.00089435 0.00161598 0.00081599 0.00142721
#   0.00719513 0.00013117]]
# text: DHCPACK on 10.100.3.37 to 00:11:43:de:35:7e via eth1
# diff: [[3.36010813e-02 1.54741973e-03 4.27337550e-03 7.59020288e-04
#   7.02720726e-03 4.88011908e-03 7.62749869e-05]]
# text: DHCPREQUEST for 10.100.3.37 10.100.2.250 from 00:11:43:de:35:7e via eth1
# diff: [[4.82185938e-03 4.32417791e-03 3.28773639e-03 3.09940939e-03
#   3.00120129e-03 5.80891767e-03 4.86633103e-03 5.64871524e-05]]
# text: DHCPDISCOVER from 00:11:43:e4:c1:f4 via eth1
# diff: [[1.66455586e-03 2.86044847e-04 1.78281128e-02 6.14311799e-03
#   7.11617935e-05]]
# text: DHCPOFFER on 10.100.28.70 to 00:11:43:e4:c1:f4 via eth1
# diff: [[0.02187788 0.01220414 0.0210457  0.00228118 0.00494184 0.00066573
#   0.00042005]]
# text: DHCPACK on 10.100.28.70 to 00:11:43:e4:c1:f4 via eth1
# diff: [[0.03327227 0.00231197 0.02321855 0.00186503 0.00491291 0.00066745
#   0.00042005]]
# text: DHCPREQUEST for 10.100.28.70 10.100.28.250 from 00:11:43:e4:c1:f4 via eth1
# diff: [[0.00542341 0.00367661 0.02151524 0.00445976 0.0028552  0.00248888
#   0.00085558 0.0005382 ]]
# text: DHCPDISCOVER from 00:11:43:e4:ad:b9 via eth1
# diff: [[1.06531615e-05 2.22337302e-03 2.09407305e-03 7.53460694e-03
#   7.61928677e-05]]
# text: DHCPOFFER on 10.100.16.2 to 00:11:43:e4:ad:b9 via eth1
# diff: [[2.13131253e-02 1.46300332e-02 1.03797910e-02 5.09066489e-04
#   7.26352591e-04 7.60493551e-03 9.48392758e-05]]
# text: DHCPACK on 10.100.16.2 to 00:11:43:e4:ad:b9 via eth1
# diff: [[3.39042461e-02 8.02102162e-04 7.31288792e-03 3.37353107e-05
#   6.83616295e-04 7.60657449e-03 9.48392758e-05]]
# text: DHCPREQUEST for 10.100.16.2 10.100.16.250 from 00:11:43:e4:ad:b9 via eth1
# diff: [[4.46046031e-03 4.82847435e-03 5.40432767e-03 2.02556201e-03
#   3.58825123e-03 5.76496562e-04 7.16497788e-03 2.81949209e-05]]
# text: DHCPDISCOVER from 00:11:43:e5:bb:60 via eth1
# diff: [[8.70138338e-05 3.22453959e-03 6.75546524e-03 6.96155592e-03
#   4.94551249e-04]]
# text: DHCPDISCOVER from 00:11:43:e5:bc:f9 via eth1
# diff: [[3.65358566e-05 1.93798053e-03 7.08760263e-03 7.70780683e-03
#   3.38541880e-04]]
# text: DHCPOFFER on 10.100.16.11 to 00:11:43:e5:bb:60 via eth1
# diff: [[0.0209789  0.01994274 0.00026629 0.00058207 0.00325603 0.00720035
#   0.00053348]]
# text: DHCPOFFER on 10.100.16.7 to 00:11:43:e5:bc:f9 via eth1
# diff: [[2.17809409e-02 3.23602346e-03 2.25664550e-03 2.91308241e-05
#   5.31497193e-03 7.72062314e-03 3.42370270e-04]]
# text: DHCPACK on 10.100.16.11 to 00:11:43:e5:bb:60 via eth1
# diff: [[3.42594059e-02 3.87508216e-03 5.10578596e-03 5.95064046e-06
#   3.13400505e-03 7.20345011e-03 5.33476367e-04]]
# text: DHCPREQUEST for 10.100.16.11 10.100.16.250 from 00:11:43:e5:bb:60 via eth1
# diff: [[0.00336439 0.00628941 0.00062131 0.00018362 0.0031282  0.00570216
#   0.00660602 0.0005766 ]]
# text: DHCPACK on 10.100.16.7 to 00:11:43:e5:bc:f9 via eth1
# diff: [[0.03287573 0.00079459 0.00893914 0.00038199 0.00523779 0.00770637
#   0.00034237]]
# text: DHCPREQUEST for 10.100.16.7 10.100.16.250 from 00:11:43:e5:bc:f9 via eth1
# diff: [[0.0056559  0.00348349 0.00160202 0.00418435 0.0055713  0.00531044
#   0.00735177 0.0002898 ]]
# text: DHCPDISCOVER from 00:11:43:e4:ae:4e via eth1
# diff: [[0.00062269 0.00123957 0.00639992 0.00628885 0.00011972]]
# text: DHCPOFFER on 10.100.16.13 to 00:11:43:e4:ae:4e via eth1
# diff: [[0.02164047 0.01474589 0.00772467 0.00121754 0.00489875 0.00565082
#   0.00019606]]
# text: DHCPDISCOVER from 00:11:43:e4:90:4c via eth1
# diff: [[0.00044227 0.00161932 0.00429536 0.00775485 0.00022353]]
# text: DHCPDISCOVER from 00:11:43:e4:b3:65 via eth1
# diff: [[9.79147761e-04 9.82486042e-04 8.19959127e-03 6.30884041e-03
#   2.45771357e-06]]
# text: DHCPOFFER on 10.100.16.16 to 00:11:43:e4:90:4c via eth1
# diff: [[0.02192397 0.00886354 0.0164771  0.00046966 0.00305688 0.00750209
#   0.00027173]]
# text: DHCPOFFER on 10.100.16.4 to 00:11:43:e4:b3:65 via eth1
# diff: [[2.11870748e-02 1.63497689e-02 7.06861110e-03 1.60566096e-03
#   6.61435787e-03 5.63361530e-03 7.90821285e-05]]
# text: DHCPACK on 10.100.16.13 to 00:11:43:e4:ae:4e via eth1
# diff: [[0.03379213 0.00032633 0.00485291 0.0007493  0.004846   0.00565248
#   0.00019606]]
# text: DHCPREQUEST for 10.100.16.13 10.100.16.250 from 00:11:43:e4:ae:4e via eth1
# diff: [[4.81525446e-03 4.47462937e-03 3.43324580e-03 2.23942162e-03
#   3.13592625e-03 3.61990071e-03 5.62194626e-03 6.44864422e-05]]
# text: DHCPACK on 10.100.16.16 to 00:11:43:e4:90:4c via eth1
# diff: [[3.31790433e-02 2.23432911e-03 2.61460591e-02 7.98095947e-05
#   2.96953671e-03 7.48781273e-03 2.71731022e-04]]
# text: DHCPACK on 10.100.16.4 to 00:11:43:e4:b3:65 via eth1
# diff: [[3.41876331e-02 1.80266262e-03 3.96376007e-03 1.12633623e-03
#   6.56241208e-03 5.63527657e-03 7.90821285e-05]]
# text: DHCPREQUEST for 10.100.16.16 10.100.16.250 from 00:11:43:e4:90:4c via eth1
# diff: [[0.00553393 0.00367487 0.00512509 0.00368275 0.00489533 0.00159586
#   0.00736018 0.00014789]]
# text: DHCPREQUEST for 10.100.16.4 10.100.16.250 from 00:11:43:e4:b3:65 via eth1
# diff: [[4.10202209e-03 5.18268088e-03 2.84845659e-03 4.84801850e-04
#   1.71547259e-03 5.34950195e-03 5.51859027e-03 4.83469525e-05]]
# text: DHCPDISCOVER from 00:11:43:e5:be:66 via eth1
# diff: [[0.00030262 0.00169368 0.00464339 0.00759117 0.00026929]]
# text: DHCPOFFER on 10.100.16.6 to 00:11:43:e5:be:66 via eth1
# diff: [[0.02135715 0.01409252 0.01014669 0.00080066 0.00320763 0.00748703
#   0.0003064 ]]
# text: DHCPACK on 10.100.16.6 to 00:11:43:e5:be:66 via eth1
# diff: [[0.03380845 0.00152326 0.00712293 0.00032511 0.00315821 0.00748867
#   0.0003064 ]]
# text: DHCPREQUEST for 10.100.16.6 10.100.16.250 from 00:11:43:e5:be:66 via eth1
# diff: [[0.00457699 0.00470478 0.0054798  0.00197957 0.00323339 0.00199477
#   0.00718545 0.00019433]]
# text: DHCPDISCOVER from 00:11:43:e5:be:5a via eth1
# diff: [[0.0006563  0.00120091 0.00676285 0.00620526 0.00010544]]
# text: DHCPOFFER on 10.100.16.12 to 00:11:43:e5:be:5a via eth1
# diff: [[0.02189349 0.01171673 0.02458005 0.00081827 0.00538383 0.00544419
#   0.00019012]]
# text: DHCPACK on 10.100.16.12 to 00:11:43:e5:be:5a via eth1
# diff: [[0.03324164 0.00211878 0.02668896 0.00040971 0.00533111 0.00544585
#   0.00019012]]
# text: DHCPREQUEST for 10.100.16.12 10.100.16.250 from 00:11:43:e5:be:5a via eth1
# diff: [[5.47134342e-03 3.76692572e-03 1.35504062e-02 3.48722082e-03
#   4.23041214e-03 4.00798284e-03 5.49259648e-03 5.37806904e-05]]
# text: DHCPDISCOVER from 00:11:43:e4:71:86 via eth1
# diff: [[0.00182086 0.00026717 0.01549699 0.00644821 0.00013474]]
# text: DHCPDISCOVER from 00:11:43:e4:a4:27 via eth1
# diff: [[1.83394205e-03 5.22489348e-04 2.19207420e-02 8.27617017e-03
#   6.99392658e-07]]
# text: DHCPOFFER on 10.100.16.3 to 00:11:43:e4:71:86 via eth1
# diff: [[0.02182272 0.00312865 0.00114069 0.00211205 0.0073215  0.00150829
#   0.00045684]]
# text: DHCPOFFER on 10.100.16.8 to 00:11:43:e4:a4:27 via eth1
# diff: [[0.02112985 0.0170662  0.00620712 0.00226923 0.00885719 0.00196349
#   0.00045586]]
# text: DHCPDISCOVER from 00:11:43:e4:78:a1 via eth1
# diff: [[0.00034066 0.00173608 0.0051311  0.00800472 0.00026671]]
# text: DHCPDISCOVER from 00:11:43:e4:a3:c3 via eth1
# diff: [[1.81991271e-03 4.87775807e-04 1.34156826e-02 9.26533290e-03
#   8.43071507e-05]]
# text: DHCPDISCOVER from 00:11:43:e4:a4:50 via eth1
# diff: [[0.00087125 0.00163081 0.00617055 0.0097859  0.00110965]]
# text: DHCPDISCOVER from 00:11:43:e4:a4:5c via eth1
# diff: [[2.14283662e-03 1.72670820e-03 4.88311315e-02 7.38705858e-03
#   3.65222726e-05]]
# text: DHCPOFFER on 10.100.16.10 to 00:11:43:e4:a4:50 via eth1
# diff: [[0.02084803 0.01992533 0.00185967 0.00153837 0.00494316 0.00924454
#   0.00108225]]
# text: DHCPOFFER on 10.100.16.15 to 00:11:43:e4:78:a1 via eth1
# diff: [[0.02108524 0.01992862 0.00348262 0.00159804 0.00330859 0.00810055
#   0.00028912]]
# text: DHCPOFFER on 10.100.16.5 to 00:11:43:e4:a3:c3 via eth1
# diff: [[0.02052067 0.01359491 0.00402211 0.00253458 0.01137387 0.00282963
#   0.00043095]]
# text: DHCPOFFER on 10.100.16.9 to 00:11:43:e4:a4:5c via eth1
# diff: [[0.02042946 0.0130383  0.01202464 0.00363832 0.0094492  0.00210098
#   0.00036526]]
# text: DHCPACK on 10.100.16.3 to 00:11:43:e4:71:86 via eth1
# diff: [[0.03281329 0.0002214  0.00620246 0.00175339 0.00727318 0.00149343
#   0.00045684]]
# text: DHCPACK on 10.100.16.8 to 00:11:43:e4:a4:27 via eth1
# diff: [[0.03417648 0.0021865  0.00297805 0.0017745  0.00883407 0.00196522
#   0.00045586]]
# text: DHCPDISCOVER from 00:11:43:e4:78:65 via eth1
# diff: [[0.00136829 0.00053113 0.00546986 0.00530184 0.0001442 ]]
# text: DHCPDISCOVER from 00:11:43:e4:ae:57 via eth1
# diff: [[1.78222066e-03 6.19080291e-04 1.96715317e-02 8.93307445e-03
#   7.04545353e-05]]
# text: DHCPOFFER on 10.100.16.1 to 00:11:43:e4:ae:57 via eth1
# diff: [[0.02053682 0.01250181 0.01336332 0.00239487 0.00884727 0.00273075
#   0.00042626]]
# text: DHCPOFFER on 10.100.16.14 to 00:11:43:e4:78:65 via eth1
# diff: [[2.07511651e-02 2.01236778e-02 3.28612124e-03 2.17793899e-03
#   2.88773053e-03 4.76232562e-03 7.13940590e-05]]
# text: DHCPREQUEST for 10.100.16.3 10.100.16.250 from 00:11:43:e4:71:86 via eth1
# diff: [[0.00573851 0.00334663 0.01794048 0.00337761 0.00396797 0.00414747
#   0.00156442 0.00057487]]
# text: DHCPREQUEST for 10.100.16.8 10.100.16.250 from 00:11:43:e4:a4:27 via eth1
# diff: [[0.00394997 0.00534716 0.00149556 0.00036626 0.00073717 0.00552795
#   0.00157781 0.00059554]]
# text: DHCPACK on 10.100.16.10 to 00:11:43:e4:a4:50 via eth1
# diff: [[0.03418602 0.00306041 0.00642864 0.00094409 0.00491363 0.00924631
#   0.00108225]]
# text: DHCPACK on 10.100.16.15 to 00:11:43:e4:78:a1 via eth1
# diff: [[0.03431361 0.00446404 0.00153202 0.00103012 0.00320335 0.0081034
#   0.00028912]]
# text: DHCPACK on 10.100.16.5 to 00:11:43:e4:a3:c3 via eth1
# diff: [[0.03404212 0.01423833 0.00084496 0.00187897 0.01134449 0.00283165
#   0.00043095]]
# text: DHCPACK on 10.100.16.9 to 00:11:43:e4:a4:5c via eth1
# diff: [[0.03422622 0.01507992 0.00985319 0.00296576 0.009459   0.00210431
#   0.00036526]]
# text: DHCPREQUEST for 10.100.16.10 10.100.16.250 from 00:11:43:e4:a4:50 via eth1
# diff: [[0.0032668  0.0067283  0.00185484 0.0011975  0.00124029 0.00528316
#   0.00912994 0.00116498]]
# text: DHCPREQUEST for 10.100.16.15 10.100.16.250 from 00:11:43:e4:78:a1 via eth1
# diff: [[0.00344214 0.00593365 0.00476029 0.00028175 0.00187936 0.00241756
#   0.00759023 0.00019233]]
# text: DHCPREQUEST for 10.100.16.5 10.100.16.250 from 00:11:43:e4:a3:c3 via eth1
# diff: [[0.00271751 0.00959345 0.00660522 0.00137068 0.00164308 0.00514486
#   0.00222866 0.00056911]]
# text: DHCPREQUEST for 10.100.16.9 10.100.16.250 from 00:11:43:e4:a4:5c via eth1
# diff: [[0.00265893 0.01127969 0.01522478 0.00232851 0.00460804 0.01039225
#   0.00139532 0.00052687]]
# text: DHCPACK on 10.100.16.1 to 00:11:43:e4:ae:57 via eth1
# diff: [[0.03407657 0.01476062 0.01070954 0.0017478  0.00881186 0.0027328
#   0.00042626]]
# text: DHCPREQUEST for 10.100.16.1 10.100.16.250 from 00:11:43:e4:ae:57 via eth1
# diff: [[0.00267569 0.01080552 0.01142506 0.00279477 0.00139608 0.00625261
#   0.00185141 0.00056915]]
# text: DHCPACK on 10.100.16.14 to 00:11:43:e4:78:65 via eth1
# diff: [[3.41158384e-02 2.82643587e-03 7.57926486e-03 1.56886475e-03
#   2.78300034e-03 4.76535186e-03 7.13940590e-05]]
# text: DHCPREQUEST for 10.100.16.14 10.100.16.250 from 00:11:43:e4:78:65 via eth1
# diff: [[3.19413672e-03 7.04608563e-03 1.42660249e-03 7.67447389e-04
#   6.05905308e-05 2.84144012e-03 4.51347523e-03 1.90824955e-04]]
# text: DHCPDISCOVER from 00:11:43:e4:c9:56 via eth1
# diff: [[0.00059069 0.00144871 0.00452247 0.00738909 0.00016046]]
# text: DHCPOFFER on 10.100.13.75 to 00:11:43:e4:c9:56 via eth1
# diff: [[0.02060601 0.02007097 0.00211504 0.00143031 0.00128863 0.0072723
#   0.00020183]]
# text: DHCPACK on 10.100.13.75 to 00:11:43:e4:c9:56 via eth1
# diff: [[0.03404213 0.00178629 0.00177412 0.00080644 0.001202   0.00727411
#   0.00020183]]
# text: DHCPREQUEST for 10.100.13.75 10.100.12.250 from 00:11:43:e4:c9:56 via eth1
# diff: [[2.95912610e-03 6.10184852e-03 9.59856582e-05 1.47119700e-03
#   3.77752459e-04 1.67248804e-03 6.95269211e-03 8.86145133e-05]]
# text: DHCPDISCOVER from 00:11:43:e1:55:31 via eth1
# diff: [[0.00092469 0.00170458 0.00885807 0.01029209 0.00100167]]
# text: DHCPOFFER on 10.100.4.20 to 00:11:43:e1:55:31 via eth1
# diff: [[0.02157218 0.01085757 0.00243552 0.00270485 0.00809531 0.00944689
#   0.00099846]]
# text: DHCPACK on 10.100.4.20 to 00:11:43:e1:55:31 via eth1
# diff: [[0.03333643 0.00086539 0.00495105 0.00312594 0.00808062 0.00944857
#   0.00099846]]
# text: DHCPREQUEST for 10.100.4.20 10.100.4.250 from 00:11:43:e1:55:31 via eth1
# diff: [[0.00498453 0.0022542  0.00585219 0.00089837 0.00480029 0.00863517
#   0.00996907 0.00104884]]
# text: DHCPDISCOVER from 00:11:43:e4:c2:e9 via eth1
# diff: [[9.57118339e-04 9.00094645e-04 8.49157308e-03 5.71802938e-03
#   4.22364923e-06]]
# text: DHCPOFFER on 10.100.23.93 to 00:11:43:e4:c2:e9 via eth1
# diff: [[2.06560290e-02 1.75682681e-02 8.26179142e-03 1.88743588e-03
#   4.76976759e-03 5.27192023e-03 6.14514003e-05]]
# text: DHCPACK on 10.100.23.93 to 00:11:43:e4:c2:e9 via eth1
# diff: [[3.41415125e-02 4.55870890e-03 1.33118984e-02 1.25683289e-03
#   4.68141080e-03 5.27382873e-03 6.14514003e-05]]
# text: DHCPREQUEST for 10.100.23.93 10.100.22.250 from 00:11:43:e4:c2:e9 via eth1
# diff: [[3.14435746e-03 9.11668912e-03 9.35560836e-03 3.86681914e-03
#   3.34040258e-04 5.37801945e-03 4.82942158e-03 4.48682246e-05]]
# text: DHCPDISCOVER from 00:11:43:e4:c7:f3 via eth1
# diff: [[0.00051769 0.0014465  0.00460439 0.00706029 0.00017791]]
# text: DHCPOFFER on 10.100.27.83 to 00:11:43:e4:c7:f3 via eth1
# diff: [[0.02146375 0.01667845 0.00936936 0.00136881 0.00303646 0.00672156
#   0.00023221]]
# text: DHCPACK on 10.100.27.83 to 00:11:43:e4:c7:f3 via eth1
# diff: [[0.03418164 0.0030297  0.00620918 0.00089561 0.00298448 0.00672321
#   0.00023221]]
# text: DHCPREQUEST for 10.100.27.83 10.100.26.250 from 00:11:43:e4:c7:f3 via eth1
# diff: [[0.00412551 0.00337665 0.00733694 0.00604939 0.0021961  0.00112131
#   0.00663261 0.00010544]]
# text: DHCPDISCOVER from 00:11:43:e4:82:63 via eth1
# diff: [[0.00140657 0.00047543 0.0042114  0.00513445 0.00015917]]
# text: DHCPOFFER on 10.100.25.89 to 00:11:43:e4:82:63 via eth1
# diff: [[2.18091721e-02 1.29051363e-02 8.86726143e-03 1.45825753e-03
#   2.97645072e-03 4.30846705e-03 6.96230410e-05]]
# text: DHCPACK on 10.100.25.89 to 00:11:43:e4:82:63 via eth1
# diff: [[3.34296021e-02 1.57219642e-03 1.12696974e-02 1.02731089e-03
#   2.93056569e-03 4.31014323e-03 6.96230410e-05]]
# text: DHCPREQUEST for 10.100.25.89 10.100.24.250 from 00:11:43:e4:82:63 via eth1
# diff: [[0.00514794 0.00259078 0.0108852  0.00142499 0.00165716 0.00162426
#   0.00447637 0.00021362]]
# text: DHCPDISCOVER from 00:11:43:e4:82:41 via eth1
# diff: [[0.00070562 0.0014027  0.0047163  0.00761383 0.00012519]]
# text: DHCPDISCOVER from 00:11:43:e4:82:d9 via eth1
# diff: [[0.00158037 0.00010783 0.01149853 0.00367617 0.00023751]]
# text: DHCPDISCOVER from 00:11:43:e4:87:bf via eth1
# diff: [[0.00030683 0.00168885 0.00460827 0.00758081 0.00026751]]
# text: DHCPOFFER on 10.100.25.85 to 00:11:43:e4:82:d9 via eth1
# diff: [[0.02185729 0.01240309 0.0170492  0.00181893 0.01202486 0.00221277
#   0.00028094]]
# text: DHCPOFFER on 10.100.25.90 to 00:11:43:e4:87:bf via eth1
# diff: [[0.02161531 0.01493901 0.00894305 0.00093449 0.00318175 0.0074463
#   0.00030546]]
# text: DHCPOFFER on 10.100.25.95 to 00:11:43:e4:82:41 via eth1
# diff: [[0.0218974  0.01161333 0.02508983 0.00066639 0.00334623 0.0071362
#   0.00018855]]
# text: DHCPACK on 10.100.25.85 to 00:11:43:e4:82:d9 via eth1
# diff: [[0.03331966 0.00207134 0.01929099 0.00139877 0.01198892 0.00221447
#   0.00028094]]
# text: DHCPACK on 10.100.25.90 to 00:11:43:e4:87:bf via eth1
# diff: [[0.03384881 0.00032459 0.00601361 0.00046395 0.00313226 0.00744794
#   0.00030546]]
# text: DHCPACK on 10.100.25.95 to 00:11:43:e4:82:41 via eth1
# diff: [[0.03323822 0.00205916 0.02719264 0.00025893 0.0032941  0.00713784
#   0.00018855]]
# text: DHCPREQUEST for 10.100.25.85 10.100.24.250 from 00:11:43:e4:82:d9 via eth1
# diff: [[0.00528036 0.00245289 0.01914027 0.00192758 0.00163602 0.0075065
#   0.00251467 0.00040349]]
# text: DHCPREQUEST for 10.100.25.90 10.100.24.250 from 00:11:43:e4:87:bf via eth1
# diff: [[0.00463517 0.00314791 0.00567059 0.00133588 0.00225215 0.00176024
#   0.00717465 0.00019438]]
# text: DHCPREQUEST for 10.100.25.95 10.100.24.250 from 00:11:43:e4:82:41 via eth1
# diff: [[5.38388650e-03 2.32979229e-03 1.15364404e-02 2.40173203e-03
#   3.11550102e-03 1.74002103e-03 7.21505114e-03 5.16106138e-05]]
# text: DHCPDISCOVER from 00:11:43:e4:82:90 via eth1
# diff: [[0.00147821 0.00037117 0.00116468 0.00482068 0.00018718]]
# text: DHCPOFFER on 10.100.25.93 to 00:11:43:e4:82:90 via eth1
# diff: [[0.02078926 0.02011763 0.00377737 0.00229973 0.00178886 0.00421386
#   0.00012746]]
# text: DHCPACK on 10.100.25.93 to 00:11:43:e4:82:90 via eth1
# diff: [[0.03413662 0.00304618 0.00816689 0.00169475 0.00169116 0.00421688
#   0.00012746]]
# text: DHCPREQUEST for 10.100.25.93 10.100.24.250 from 00:11:43:e4:82:90 via eth1
# diff: [[0.00311258 0.00561244 0.00143624 0.00186153 0.00096371 0.00068665
#   0.00412928 0.00025214]]
# text: DHCPDISCOVER from 00:11:43:e4:79:cd via eth1
# diff: [[1.55794936e-03 1.99789002e-05 1.08902780e-03 4.11900758e-03
#   1.77706308e-04]]
# text: DHCPOFFER on 10.100.25.83 to 00:11:43:e4:79:cd via eth1
# diff: [[0.0206457  0.01836829 0.0064742  0.00228722 0.0062793  0.00194542
#   0.00031806]]
# text: DHCPDISCOVER from 00:11:43:e4:79:40 via eth1
# diff: [[0.00031696 0.00184938 0.00715574 0.00856822 0.00029034]]
# text: DHCPDISCOVER from 00:11:43:e4:82:66 via eth1
# diff: [[1.91328610e-03 5.11144567e-04 2.19366750e-02 8.37520361e-03
#   3.42935515e-05]]
# text: DHCPDISCOVER from 00:11:43:e4:83:b5 via eth1
# diff: [[0.00019493 0.00276826 0.00384626 0.00848853 0.00076451]]
# text: DHCPDISCOVER from 00:11:43:e4:87:a2 via eth1
# diff: [[0.00054939 0.00217241 0.00356789 0.00917005 0.00094542]]
# text: DHCPDISCOVER from 00:11:43:e4:88:74 via eth1
# diff: [[2.28325444e-04 2.27173859e-03 1.20220520e-03 8.38636936e-03
#   6.35254125e-05]]
# text: DHCPOFFER on 10.100.25.82 to 00:11:43:e4:79:40 via eth1
# diff: [[0.0211681  0.01988648 0.00808695 0.00157868 0.00560753 0.008788
#   0.0003026 ]]
# text: DHCPOFFER on 10.100.25.86 to 00:11:43:e4:82:66 via eth1
# diff: [[0.02112429 0.02004331 0.00559659 0.00274635 0.00816251 0.00222733
#   0.00048384]]
# text: DHCPOFFER on 10.100.25.88 to 00:11:43:e4:87:a2 via eth1
# diff: [[0.02172626 0.01341873 0.00225548 0.00042674 0.00445872 0.00830815
#   0.00092576]]
# text: DHCPOFFER on 10.100.25.91 to 00:11:43:e4:88:74 via eth1
# diff: [[2.19156765e-02 9.85583056e-03 2.02980722e-02 2.51812264e-05
#   5.08667516e-04 8.32786340e-03 5.83409537e-05]]
# text: DHCPOFFER on 10.100.25.96 to 00:11:43:e4:83:b5 via eth1
# diff: [[0.02101497 0.01990095 0.00112229 0.00089432 0.00521891 0.00788824
#   0.00073786]]
# text: DHCPDISCOVER from 00:11:43:e4:74:c7 via eth1
# diff: [[1.64316817e-03 2.81543287e-05 1.51690224e-03 4.40842581e-03
#   2.02443577e-04]]
# text: DHCPDISCOVER from 00:11:43:e4:82:17 via eth1
# diff: [[1.97116432e-03 6.89763555e-04 1.74680279e-02 9.95246106e-03
#   4.44034472e-05]]
# text: DHCPDISCOVER from 00:11:43:e4:82:3e via eth1
# diff: [[0.00022066 0.00187392 0.00747348 0.00829922 0.00031769]]
# text: DHCPDISCOVER from 00:11:43:e4:83:93 via eth1
# diff: [[1.11081820e-03 9.05539376e-04 8.42505479e-03 6.42264582e-03
#   4.35487607e-05]]
# text: DHCPDISCOVER from 00:11:43:e4:88:b1 via eth1
# diff: [[2.04228652e-03 8.10835442e-04 1.61043570e-02 8.40201579e-03
#   1.61694877e-05]]
# text: DHCPOFFER on 10.100.25.81 to 00:11:43:e4:82:3e via eth1
# diff: [[0.0218617  0.01196254 0.0179303  0.00038489 0.0062358  0.00830043
#   0.00034412]]
# text: DHCPOFFER on 10.100.25.84 to 00:11:43:e4:88:b1 via eth1
# diff: [[0.02176739 0.01400576 0.00350119 0.00813443 0.01372766 0.00121706
#   0.0005829 ]]
# text: DHCPOFFER on 10.100.25.87 to 00:11:43:e4:82:17 via eth1
# diff: [[0.02064252 0.01884879 0.00359781 0.00246467 0.00760306 0.00327577
#   0.00048208]]
# text: DHCPOFFER on 10.100.25.92 to 00:11:43:e4:74:c7 via eth1
# diff: [[0.02103915 0.02005244 0.00109709 0.00257506 0.00829729 0.0021222
#   0.00033983]]
# text: DHCPOFFER on 10.100.25.94 to 00:11:43:e4:83:93 via eth1
# diff: [[2.16340427e-02 1.48752074e-02 7.71930893e-03 1.46438299e-03
#   6.95488336e-03 5.66044435e-03 4.23981832e-05]]
# text: DHCPACK on 10.100.25.82 to 00:11:43:e4:79:40 via eth1
# diff: [[0.03436037 0.00486044 0.00296567 0.00102038 0.0055074  0.00879082
#   0.0003026 ]]
# text: DHCPACK on 10.100.25.83 to 00:11:43:e4:79:cd via eth1
# diff: [[0.03411226 0.00255894 0.01218673 0.00166085 0.00622144 0.00194735
#   0.00031806]]
# text: DHCPACK on 10.100.25.86 to 00:11:43:e4:82:66 via eth1
# diff: [[0.03432512 0.00486331 0.00053295 0.00217902 0.00811152 0.00223029
#   0.00048384]]
# text: DHCPACK on 10.100.25.88 to 00:11:43:e4:87:a2 via eth1
# diff: [[3.36071401e-02 7.45066909e-04 3.76064687e-04 1.65741447e-05
#   4.48688471e-03 8.30985101e-03 9.25758106e-04]]
# text: DHCPACK on 10.100.25.91 to 00:11:43:e4:88:74 via eth1
# diff: [[3.31986211e-02 2.09337964e-03 3.03377198e-02 3.76563393e-04
#   5.81223410e-04 8.31366707e-03 5.83409537e-05]]
# text: DHCPACK on 10.100.25.96 to 00:11:43:e4:83:b5 via eth1
# diff: [[0.03427966 0.00400628 0.00378437 0.0003214  0.00531404 0.00789131
#   0.00073786]]
# text: DHCPREQUEST for 10.100.25.82 10.100.24.250 from 00:11:43:e4:79:40 via eth1
# diff: [[0.003412   0.00445248 0.00538536 0.00115488 0.00125967 0.00449116
#   0.00814876 0.00021793]]
# text: DHCPREQUEST for 10.100.25.83 10.100.24.250 from 00:11:43:e4:79:cd via eth1
# diff: [[0.00284154 0.00666424 0.00433607 0.00125681 0.00185471 0.00644864
#   0.00176581 0.00043978]]
# text: DHCPREQUEST for 10.100.25.86 10.100.24.250 from 00:11:43:e4:82:66 via eth1
# diff: [[0.00335882 0.00450988 0.00615443 0.00176857 0.00053943 0.00542817
#   0.00203421 0.00061785]]
# text: DHCPREQUEST for 10.100.25.88 10.100.24.250 from 00:11:43:e4:87:a2 via eth1
# diff: [[0.00494049 0.00282812 0.00136442 0.00273308 0.00312338 0.00409004
#   0.00866339 0.00099462]]
# text: DHCPREQUEST for 10.100.25.91 10.100.24.250 from 00:11:43:e4:88:74 via eth1
# diff: [[5.42544963e-03 2.27268002e-03 5.67614347e-03 2.85545194e-03
#   4.13458184e-03 1.63887636e-04 8.05856932e-03 8.81511028e-05]]
# text: DHCPREQUEST for 10.100.25.96 10.100.24.250 from 00:11:43:e4:83:b5 via eth1
# diff: [[0.00328066 0.00484699 0.00233849 0.00070412 0.00187686 0.00446745
#   0.00798165 0.00081486]]
# text: DHCPACK on 10.100.25.81 to 00:11:43:e4:82:3e via eth1
# diff: [[3.33138340e-02 1.76597933e-03 2.01424295e-02 2.93742443e-05
#   6.18937256e-03 8.30205971e-03 3.44115031e-04]]
# text: DHCPACK on 10.100.25.84 to 00:11:43:e4:88:b1 via eth1
# diff: [[0.03350065 0.00187277 0.00602646 0.0085559  0.01371941 0.00121877
#   0.0005829 ]]
# text: DHCPACK on 10.100.25.87 to 00:11:43:e4:82:17 via eth1
# diff: [[0.03409715 0.00136987 0.00974611 0.0018411  0.00757169 0.00327767
#   0.00048208]]
# text: DHCPACK on 10.100.25.92 to 00:11:43:e4:74:c7 via eth1
# diff: [[0.03427813 0.00440365 0.0038361  0.00199852 0.00822418 0.00212518
#   0.00033983]]
# text: DHCPACK on 10.100.25.94 to 00:11:43:e4:83:93 via eth1
# diff: [[3.38112720e-02 2.65829914e-04 4.82338620e-03 9.93143843e-04
#   6.90343458e-03 5.66210532e-03 4.23981832e-05]]
# text: DHCPREQUEST for 10.100.25.81 10.100.24.250 from 00:11:43:e4:82:3e via eth1
# diff: [[0.00530088 0.00244268 0.02044018 0.00271436 0.0034177  0.00487755
#   0.00790155 0.00024417]]
# text: DHCPREQUEST for 10.100.25.84 10.100.24.250 from 00:11:43:e4:88:b1 via eth1
# diff: [[5.04139507e-03 2.73102985e-03 5.76870987e-03 1.65435814e-03
#   4.38574893e-05 7.90388548e-03 2.32099552e-03 6.17450394e-04]]
# text: DHCPREQUEST for 10.100.25.87 10.100.24.250 from 00:11:43:e4:82:17 via eth1
# diff: [[0.00286938 0.00657234 0.00475164 0.00115206 0.00203872 0.0056941
#   0.00286982 0.00061846]]
# text: DHCPREQUEST for 10.100.25.92 10.100.24.250 from 00:11:43:e4:74:c7 via eth1
# diff: [[0.00329614 0.0047734  0.00280671 0.00181131 0.0005566  0.00685711
#   0.00207904 0.00046458]]
# text: DHCPREQUEST for 10.100.25.94 10.100.24.250 from 00:11:43:e4:83:93 via eth1
# diff: [[4.67660583e-03 3.09591062e-03 5.08618833e-03 7.36810884e-04
#   1.49106837e-03 5.47057919e-03 5.77365564e-03 9.83190715e-05]]
# text: DHCPDISCOVER from 00:14:22:11:fa:06 via eth1
# diff: [[0.00018462 0.00203819 0.00464775 0.00823448 0.00018295]]
# text: DHCPOFFER on 10.100.33.43 to 00:14:22:11:fa:06 via eth1
# diff: [[0.02154724 0.01564308 0.01029555 0.00080391 0.00316204 0.00832266
#   0.00019715]]
# text: DHCPACK on 10.100.33.43 to 00:14:22:11:fa:06 via eth1
# diff: [[0.03399966 0.00144474 0.00722819 0.00033296 0.00311747 0.00832429
#   0.00019715]]
# text: DHCPREQUEST for 10.100.33.43 10.100.32.250 from 00:14:22:11:fa:06 via eth1
# diff: [[0.00436415 0.00303135 0.00779862 0.00615968 0.00341023 0.0035471
#   0.0079151  0.00017603]]
# text: DHCPDISCOVER from 00:11:43:e8:12:31 via eth1
# diff: [[2.15913477e-03 1.06867680e-03 2.30715554e-02 8.50426602e-03
#   5.35853008e-05]]
# text: DHCPOFFER on 10.100.10.52 to 00:11:43:e8:12:31 via eth1
# diff: [[0.0215118  0.01688988 0.00929742 0.01138085 0.01035083 0.0017159
#   0.00062069]]
# text: DHCPACK on 10.100.10.52 to 00:11:43:e8:12:31 via eth1
# diff: [[0.03405382 0.00344881 0.00617445 0.01182236 0.01034388 0.00171761
#   0.00062069]]
# text: DHCPREQUEST for 10.100.10.52 10.100.10.250 from 00:11:43:e8:12:31 via eth1
# diff: [[0.00425693 0.00334961 0.0079564  0.0007069  0.00065089 0.00453591
#   0.00269489 0.00064898]]
# text: DHCPDISCOVER from 00:11:43:e4:7e:c2 via eth1
# diff: [[1.53812679e-03 2.94741616e-05 6.20246519e-03 3.73960129e-03
#   1.97516554e-04]]
# text: DHCPOFFER on 10.100.23.26 to 00:11:43:e4:7e:c2 via eth1
# diff: [[0.02149427 0.01657082 0.00943494 0.0020966  0.00986444 0.00178107
#   0.0002948 ]]
# text: DHCPACK on 10.100.23.26 to 00:11:43:e4:7e:c2 via eth1
# diff: [[0.03410693 0.00293085 0.00629029 0.00162197 0.00983013 0.00178277
#   0.0002948 ]]
# text: DHCPREQUEST for 10.100.23.26 10.100.22.250 from 00:11:43:e4:7e:c2 via eth1
# diff: [[0.0046537  0.00608813 0.00439512 0.0036288  0.0029581  0.0090695
#   0.00159554 0.00041776]]
# text: DHCPDISCOVER from 00:14:22:16:43:a2 via eth1
# diff: [[0.00081207 0.00156948 0.00718004 0.01017836 0.00118373]]
# text: DHCPOFFER on 10.100.33.84 to 00:14:22:16:43:a2 via eth1
# diff: [[0.02162283 0.0145804  0.00973698 0.00091856 0.0063124  0.00938007
#   0.00116339]]
# text: DHCPACK on 10.100.33.84 to 00:14:22:16:43:a2 via eth1
# diff: [[3.38340699e-02 6.12705575e-06 6.83127431e-03 4.50647572e-04
#   6.29226521e-03 9.38175344e-03 1.16338635e-03]]
# text: DHCPREQUEST for 10.100.33.84 10.100.32.250 from 00:14:22:16:43:a2 via eth1
# diff: [[0.00456596 0.00285353 0.00643217 0.00520421 0.0032079  0.00691371
#   0.00981472 0.00123092]]
# text: DHCPDISCOVER from 00:11:43:e3:b9:f7 via eth1
# diff: [[0.00052955 0.00143286 0.00468488 0.00703095 0.00017287]]
# text: DHCPOFFER on 10.100.24.251 to 00:11:43:e3:b9:f7 via eth1
# diff: [[0.02081998 0.0212025  0.00136631 0.00169717 0.00144615 0.00686704
#   0.00021675]]
# text: DHCPACK on 10.100.24.251 to 00:11:43:e3:b9:f7 via eth1
# diff: [[0.03424107 0.00443861 0.00257339 0.00108142 0.00135964 0.00686883
#   0.00021675]]
# text: DHCPREQUEST for 10.100.24.251 10.100.24.250 from 00:11:43:e3:b9:f7 via eth1
# diff: [[0.00298953 0.00619334 0.00090955 0.0009029  0.0002104  0.00174936
#   0.00659926 0.00010072]]
# text: DHCPDISCOVER from 00:11:43:e3:ba:85 via eth1
# diff: [[0.0013095  0.00038762 0.00106057 0.00417464 0.00014197]]
# text: DHCPOFFER on 10.100.16.251 to 00:11:43:e3:ba:85 via eth1
# diff: [[2.21190593e-02 1.29075267e-02 2.31346247e-02 1.92258546e-03
#   5.60151664e-03 3.16500186e-03 8.02463005e-05]]
# text: DHCPACK on 10.100.16.251 to 00:11:43:e3:ba:85 via eth1
# diff: [[3.33870360e-02 4.03106237e-03 2.96856962e-02 1.50905664e-03
#   5.54057028e-03 3.15777680e-03 8.02463005e-05]]
# text: DHCPREQUEST for 10.100.16.251 10.100.16.250 from 00:11:43:e3:ba:85 via eth1
# diff: [[0.00549888 0.00373885 0.01033726 0.00303075 0.00350219 0.0017347
#   0.00330364 0.00020047]]
# text: DHCPDISCOVER from 00:11:43:e3:b8:e0 via eth1
# diff: [[0.00069091 0.00124728 0.00621409 0.00663123 0.0001043 ]]
# text: DHCPOFFER on 10.100.28.251 to 00:11:43:e3:b8:e0 via eth1
# diff: [[0.02224487 0.00616491 0.00824916 0.0009256  0.00527593 0.00606034
#   0.00018572]]
# text: DHCPACK on 10.100.28.251 to 00:11:43:e3:b8:e0 via eth1
# diff: [[0.0331309  0.00401537 0.01320022 0.00057564 0.00518908 0.00604592
#   0.00018572]]
# text: DHCPREQUEST for 10.100.28.251 10.100.24.250 from 00:11:43:e3:b8:e0 via eth1
# diff: [[5.68284533e-03 1.90207395e-03 3.09460972e-02 2.57839019e-03
#   4.02533037e-03 2.86832992e-03 6.13385816e-03 3.81303633e-05]]
# text: DHCPDISCOVER from 00:11:43:d8:f4:ac via eth1
# diff: [[9.45947704e-04 8.01905431e-04 8.35222075e-03 5.07733710e-03
#   1.02333603e-05]]
# text: DHCPOFFER on 10.100.85.101 to 00:11:43:d8:f4:ac via eth1
# diff: [[2.20711326e-02 1.39933874e-02 1.80574582e-02 1.41515560e-03
#   7.00040738e-03 4.22501356e-03 7.94418837e-05]]
# text: DHCPACK on 10.100.85.101 to 00:11:43:d8:f4:ac via eth1
# diff: [[3.34869353e-02 3.69255212e-03 2.02613085e-02 9.93821452e-04
#   6.95027935e-03 4.22669067e-03 7.94418837e-05]]
# text: DHCPREQUEST for 10.100.85.101 10.100.20.250 from 00:11:43:d8:f4:ac via eth1
# diff: [[5.41537223e-03 4.03950388e-03 2.25800678e-02 6.23600470e-04
#   3.80434591e-03 5.83031140e-03 4.25485388e-03 5.42073708e-05]]
# text: DHCPDISCOVER from 00:11:43:d8:f4:aa via eth1
# diff: [[0.00049626 0.00138499 0.00510658 0.00660287 0.00017345]]
# text: DHCPOFFER on 10.100.21.101 to 00:11:43:d8:f4:aa via eth1
# diff: [[0.02176253 0.01722285 0.01003226 0.00149513 0.0035539  0.00614136
#   0.00023555]]
# text: DHCPACK on 10.100.21.101 to 00:11:43:d8:f4:aa via eth1
# diff: [[0.03415465 0.00411445 0.00699439 0.00102747 0.0035015  0.00614301
#   0.00023555]]
# text: DHCPREQUEST for 10.100.21.101 10.100.20.250 from 00:11:43:d8:f4:aa via eth1
# diff: [[0.00459994 0.00488659 0.00526937 0.00060167 0.00314218 0.00234937
#   0.00607513 0.00010741]]
# text: DHCPDISCOVER from 00:11:43:e4:7c:3d via eth1
# diff: [[1.66661336e-03 2.91181645e-04 1.80546350e-02 6.18191279e-03
#   6.91054234e-05]]
# text: DHCPOFFER on 10.100.25.99 to 00:11:43:e4:7c:3d via eth1
# diff: [[0.0219559  0.00545173 0.00429484 0.00240002 0.00506766 0.00067933
#   0.00042353]]
# text: DHCPACK on 10.100.25.99 to 00:11:43:e4:7c:3d via eth1
# diff: [[0.0331053  0.00283786 0.01260554 0.00204928 0.00501758 0.00066439
#   0.00042353]]
# text: DHCPREQUEST for 10.100.25.99 10.100.24.250 from 00:11:43:e4:7c:3d via eth1
# diff: [[0.00550194 0.00215009 0.00052238 0.00247166 0.00211182 0.00116836
#   0.00099784 0.00054109]]
# text: DHCPDISCOVER from 00:11:43:e4:da:d5 via eth1
# diff: [[1.78031400e-03 2.93005067e-04 8.31692009e-03 8.66531722e-03
#   8.89865229e-05]]
# text: DHCPOFFER on 10.100.25.98 to 00:11:43:e4:da:d5 via eth1
# diff: [[0.02167555 0.01479613 0.00545575 0.00176873 0.01507227 0.00139349
#   0.00043632]]
# text: DHCPACK on 10.100.25.98 to 00:11:43:e4:da:d5 via eth1
# diff: [[0.03370238 0.00112331 0.00267047 0.0013059  0.01505758 0.0013952
#   0.00043632]]
# text: DHCPREQUEST for 10.100.25.98 10.100.24.250 from 00:11:43:e4:da:d5 via eth1
# diff: [[0.00479665 0.00297927 0.00248534 0.00147216 0.0006164  0.00521867
#   0.00238399 0.00053199]]
# text: DHCPDISCOVER from 00:11:43:e6:14:6c via eth1
# diff: [[0.00073155 0.0012867  0.00573651 0.00704104 0.00010059]]
# text: DHCPOFFER on 10.100.14.95 to 00:11:43:e6:14:6c via eth1
# diff: [[0.02061027 0.01987738 0.0027201  0.00154059 0.00240968 0.00676024
#   0.00015454]]
# text: DHCPACK on 10.100.14.95 to 00:11:43:e6:14:6c via eth1
# diff: [[0.03404946 0.00130066 0.00110872 0.00091463 0.00232148 0.00676206
#   0.00015454]]
# text: DHCPREQUEST for 10.100.14.95 10.100.14.250 from 00:11:43:e6:14:6c via eth1
# diff: [[3.34622010e-03 8.76178097e-03 1.21957737e-02 5.85338992e-03
#   8.16526560e-04 2.56882266e-03 6.37844221e-03 4.39415531e-05]]
# text: DHCPDISCOVER from 00:11:43:d4:a4:1f via eth1
# diff: [[0.00018276 0.00298685 0.00061965 0.00766981 0.00062178]]
# text: DHCPOFFER on 10.100.88.115 to 00:11:43:d4:a4:1f via eth1
# diff: [[0.02081422 0.02058223 0.00489778 0.00066294 0.00334231 0.00739888
#   0.00061245]]
# text: DHCPACK on 10.100.88.115 to 00:11:43:d4:a4:1f via eth1
# diff: [[3.42635739e-02 2.83918884e-03 1.60651108e-03 5.62973375e-05
#   3.40606928e-03 7.40077381e-03 6.12448662e-04]]
# text: DHCPREQUEST for 10.100.88.115 10.100.24.250 from 00:11:43:d4:a4:1f via eth1
# diff: [[0.00293334 0.00638637 0.00298313 0.00028393 0.00115385 0.00141384
#   0.00734366 0.00068659]]
# text: DHCPDISCOVER from 00:11:43:d4:a4:1d via eth1
# diff: [[1.56789259e-03 4.47874142e-05 1.28536137e-03 4.30896200e-03
#   1.67769179e-04]]
# text: DHCPOFFER on 10.100.24.115 to 00:11:43:d4:a4:1d via eth1
# diff: [[0.02127577 0.02111317 0.00280078 0.00284216 0.00772293 0.00172495
#   0.00032508]]
# text: DHCPACK on 10.100.24.115 to 00:11:43:d4:a4:1d via eth1
# diff: [[0.03449018 0.00680074 0.0021654  0.00227526 0.00765102 0.00172792
#   0.00032508]]
# text: DHCPREQUEST for 10.100.24.115 10.100.24.250 from 00:11:43:d4:a4:1d via eth1
# diff: [[0.00332288 0.0046809  0.00415732 0.00173664 0.00044009 0.00616589
#   0.00169539 0.00044877]]
# text: DHCPDISCOVER from 00:11:43:e4:7d:6a via eth1
# diff: [[5.18489674e-05 2.34324066e-03 7.30187208e-04 7.75616540e-03
#   6.57966669e-05]]
# text: DHCPOFFER on 10.100.18.73 to 00:11:43:e4:7d:6a via eth1
# diff: [[2.06981879e-02 1.50723153e-02 2.19306699e-03 9.87252876e-04
#   1.70927899e-03 8.22262612e-03 3.43513983e-05]]
# text: DHCPACK on 10.100.18.73 to 00:11:43:e4:7d:6a via eth1
# diff: [[3.42372606e-02 1.10119324e-02 1.12031274e-03 3.42141862e-04
#   1.78179040e-03 8.22456290e-03 3.43513983e-05]]
# text: DHCPREQUEST for 10.100.18.73 10.100.18.250 from 00:11:43:e4:7d:6a via eth1
# diff: [[2.35441159e-03 8.61776389e-03 1.72434263e-03 7.75906010e-03
#   1.05145341e-04 5.51123540e-04 7.44548997e-03 7.46373799e-05]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-8a9b32c4acd1> in <cell line: 2>()
#       1 # with np.printoptions(precision=4, suppress=True):
# ----> 2 for i, data in enumerate(train_batch):
#       3   text = " ".join([ f"{t}" for t in unique_trainset["Tokens"].iloc[i] ])
#       4   if text.endswith("via eth1"):
#       5     print("text:", text)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     795   def __next__(self):
#     796     try:
# --> 797       return self._next_internal()
#     798     except errors.OutOfRangeError:
#     799       raise StopIteration
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     778     # to communicate that there is no more data to iterate over.
#     779     with context.execution_mode(context.SYNC):
# --> 780       ret = gen_dataset_ops.iterator_get_next(
#     781           self._iterator_resource,
#     782           output_types=self._flat_output_types,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    3009   if tld.is_eager:
#    3010     try:
# -> 3011       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3012         _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
#    3013         "output_shapes", output_shapes)
#
# KeyboardInterrupt:

# %%
trainset[['Content', 'Tokens']]
# Out:
#                                                    Content  \
# 0                     tftp: client does not accept options
# 1        warning: unable to look up public/pickup: No s...
# 2        warning: unable to look up public/pickup: No s...
# 3        warning: unable to look up public/pickup: No s...
# 4        warning: unable to look up public/pickup: No s...
# ...                                                    ...
# 3990047     (root) CMD (/projects/tbird/temps/get_temps e)
# 3990048  data_thread() got not answer from any [Thunder...
# 3990049  Instrumentation Service EventID: 1053 Temperat...
# 3990050                        Got trap from peer on fd 13
# 3990051           synchronized to 10.100.28.250, stratum 3
#
#                                                     Tokens
# 0              [tftp:, client, does, not, accept, options]
# 1        [warning:, unable, to, look, up, public/pickup...
# 2        [warning:, unable, to, look, up, public/pickup...
# 3        [warning:, unable, to, look, up, public/pickup...
# 4        [warning:, unable, to, look, up, public/pickup...
# ...                                                    ...
# 3990047    [root, CMD, /projects/tbird/temps/get_temps, e]
# 3990048  [data_thread, got, not, answer, from, any, Thu...
# 3990049  [Instrumentation, Service, EventID:, 1053, Tem...
# 3990050                [Got, trap, from, peer, on, fd, 13]
# 3990051      [synchronized, to, 10.100.28.250, stratum, 3]
#
# [3990052 rows x 2 columns]
# Warning: total number of rows (3990052) exceeds max_rows (20000). Limiting to first (20000) rows.
